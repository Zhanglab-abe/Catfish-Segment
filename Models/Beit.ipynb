# %% [markdown]
# # Prepare the environment

# %%
# ! tar -xvf /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/data/ade/ADEChallengeData2016/data.tarb

# %%
# !pip3 install openmim
# !mim install mmcv-full

# !pip3 install -U openmim

# %%
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install mmcv-full==1.4.2 -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html



# export MKL_THREADING_LAYER=GNU
# !mim install mmcv-full
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html
# ...

# %%
# %cd /home/agricoptics/Desktop/CatFish
# Out:
# /home/agricoptics/Desktop/CatFish

# %%
# !cp -r /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation_old/data /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation_custom_base/data

# %%
# !cp -r  /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation_custom_base /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation_beitv2

# %%
# !git clone https://github.com/open-mmlab/mmsegmentation.git
# %cd mmsegmentation

# %cd mmsegmentation

# !pip install -e .
# Out:
# /home/agricoptics/Desktop/CatFish/mmsegmentation
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Obtaining file:///home/agricoptics/Desktop/CatFish/mmsegmentation
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: mmsegmentation
#     Found existing installation: mmsegmentation 0.29.1
#     Uninstalling mmsegmentation-0.29.1:
#       Successfully uninstalled mmsegmentation-0.29.1
#   Running setup.py develop for mmsegmentation
# ...

# %%
import mmseg
print(mmseg.__version__)
# 预期输出：0.24.1 或其他版本号
# Expected output: 0.24.1 or other version number
# Out:
# 0.29.1

# %% [markdown]
# # train

# %%
# !pip install mmcv-full
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...

# %%
import pytorch
# !nvcc --version
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c0b060d07a6c> in <module>
# ----> 1 import pytorch
#       2 get_ipython().system('nvcc --version')
#
# ModuleNotFoundError: No module named 'pytorch'

# %%
# !bash tools/dist_train.sh \
    /home/agricoptics/Desktop/CatFish/mmsegmentation/configs/beit/upernet_beit-base_640x640_160k_ade20k_ms.py 1 \
    --work-dir /home/agricoptics/Desktop/CatFish/mmsegmentation/checkpoints --seed 0  --deterministic \
    --options model.pretrained=https://conversationhub.blob.core.windows.net/beit-share-public/beit/beit_base_patch16_224_pt22k_ft22k.pth
# Out:
# /home/agricoptics/snap/jupyter/common/lib/python3.7/site-packages/torch/distributed/launch.py:164: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   "The module torch.distributed.launch is deprecated "
# The module torch.distributed.launch is deprecated and going to be removed in future.Migrate to torch.distributed.run
# WARNING:torch.distributed.run:--use_env is deprecated and will be removed in future releases.
#  Please read local_rank from `os.environ('LOCAL_RANK')` instead.
# INFO:torch.distributed.launcher.api:Starting elastic_operator with launch configs:
#   entrypoint       : tools/train.py
#   min_nodes        : 1
#   max_nodes        : 1
#   nproc_per_node   : 1
#   run_id           : none
#   rdzv_backend     : static
#   rdzv_endpoint    : 127.0.0.1:29500
#   rdzv_configs     : {'rank': 0, 'timeout': 900}
#   max_restarts     : 3
#   monitor_interval : 5
#   log_dir          : None
#   metrics_cfg      : {}
#
# ...

# %%
# !bash /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/dist_train.sh \
#     /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/configs/beit/my_upernet_beit-base_640x640_160k_ade20k_ms.py 1 \
#     --work-dir /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/checkpoints --seed 0  --deterministic \
#     --options model.pretrained=https://conversationhub.blob.core.windows.net/beit-share-public/beit/beit_base_patch16_224_pt22k_ft22k.pth

# %%
# !bash /home/agricoptics/Desktop/CatFish/mmsegmentation/tools/dist_train.sh \
#     /home/agricoptics/Desktop/CatFish/mmsegmentation/configs/beit/my_upernet_beit-base_640x640_160k_ade20k_ms.py 1 \
#     --resume-from /home/agricoptics/Desktop/CatFish/mmsegmentation/checkpoints/iter_39000.pth \
#     --deterministic
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/distributed/launch.py:180: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# 2022-12-20 23:18:46,958 - mmseg - INFO - Multi-processing start method is `None`
# ...

# %% [markdown]
# # test

# %%
# !python \
    /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/demo/image_demo.py \
    /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/data/ade/ADEChallengeData2016/test/cl8i0klwwdbme08140gykc8xp_3.jpg \
    /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/save01/upernet_beit-base_640x640_160k_ade20k_ms.py \
    /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/save01/iter_20000.pth --device cuda --out-file /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/result/result.jpg

# %%
CONFIG_FILE="/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/save/upernet_beit-base_640x640_160k_ade20k_ms.py"
MODEL_FILE="/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/save/iter_3000.pth"
OUTPUT_FILE="/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/result"
# !python /home/masters/twitterDir/demo/mmsegmentation/tools/test.py \
    ${CONFIG_FILE} \
    ${MODEL_FILE}  \
    --out ${OUTPUT_FILE}/results.pkl \
    --eval mIoU cityscapes \

# %%
# mIoU, mAcc, aAcc 

logPath = "save-del/20221209_005605.log.json"

# !python /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/${logPath} --keys mIoU mAcc aAcc --legend mIoU mAcc aAcc --out /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/result/chart.jpg


# loss 
# !python /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/${logPath} --keys loss --legend loss --out /content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/result/chart_loss.jpg
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py", line 128, in <module>
#     main()
#   File "/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py", line 123, in main
#     log_dicts = load_json_logs(json_logs)
#   File "/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py", line 104, in load_json_logs
#     with open(json_log, 'r') as log_file:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/-del/20221209_005605.log.json'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py", line 128, in <module>
#     main()
#   File "/content/drive/MyDrive/catfish/tianqi/code/mmsegmentation/tools/analyze_logs.py", line 123, in main
#     log_dicts = load_json_logs(json_logs)
# ...
